# %%
from google.colab import drive 
drive.mount('/content/gdrive')
import pandas as pd
# Out:
# Mounted at /content/gdrive

# %%
Data ='/content/gdrive/MyDrive/Datasets- Game/Q3_Sikka data.csv'

# %%
# !unzip '/content/gdrive/MyDrive/Datasets-20221217T024213Z-001.zip'
# Out:
# Archive:  /content/gdrive/MyDrive/Datasets-20221217T024213Z-001.zip
#   inflating: Datasets/Q3_Sikka data.csv
#   inflating: Datasets/Q2_User offer completion data.csv
#   inflating: Datasets/Q2_User offer data.csv
#   inflating: Datasets/Q2_users signup.csv
#   inflating: Datasets/Q2_rewards details.csv
#   inflating: Datasets/Q4_ADX_Sample_data.csv

# %%
df= pd.read_csv('Datasets/Q3_Sikka data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        46 non-null     object
#  1   DAU         46 non-null     int64
#  2   Installs    46 non-null     int64
#  3   Uninstalls  46 non-null     int64
#  4   Signups     46 non-null     int64
#  5   Referrals   31 non-null     float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 2.3+ KB

# %%
df.isnull().sum()
# Out:
# Date           0
# DAU            0
# Installs       0
# Uninstalls     0
# Signups        0
# Referrals     15
# dtype: int64

# %%
import seaborn as sns
from matplotlib import pyplot as plt

sns.heatmap(df.isnull(),cbar=False,cmap='viridis')

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')

# %%
plt.figure(figsize=(5,5))
plt.scatter(x='DAU',y='Referrals',data=df)
plt.xlabel('DAU')
plt.ylabel('Referrals')
# Out:
# Text(0, 0.5, 'Referrals')

# %%
plt.figure(figsize=(5,5))
plt.scatter(x='DAU',y='Installs',data=df)
plt.xlabel('DAU')
plt.ylabel('Installs') 
plt.figure(figsize=(5,5))
plt.scatter(x='DAU',y='Uninstalls',data=df)
plt.xlabel('DAU')
plt.ylabel('Uninstalls') 
plt.figure(figsize=(5,5))
plt.scatter(x='DAU',y='Signups',data=df)
plt.xlabel('DAU')
plt.ylabel('Signups	')
# Out:
# Text(0, 0.5, 'Signups\t')
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df.describe()
# Out:
#                 DAU     Installs   Uninstalls      Signups    Referrals
# count     46.000000    46.000000    46.000000    46.000000    31.000000
# mean   17788.586957  5064.978261  5494.347826  2550.891304   770.161290
# std     4892.080923  1624.796773  1402.885078   991.987348   249.692891
# min    12042.000000  3074.000000  3815.000000  1363.000000   384.000000
# 25%    13380.250000  3708.750000  4321.250000  1729.500000   543.500000
# 50%    15059.500000  4479.500000  4738.000000  2065.500000   801.000000
# 75%    23472.750000  6332.000000  6741.750000  3369.000000   961.000000
# max    25156.000000  8937.000000  8215.000000  4974.000000  1193.000000

# %%
df.plot(kind='line',figsize=(20,6));
plt.plot('Referrals', '*-', color='red', markersize=10)

# %% [markdown]
# 15 Referrals which are missing needs to be predicted

# %%
df.head()
# Out:
#          Date    DAU  Installs  Uninstalls  Signups  Referrals
# 0  2022-10-01  24071      6630        6994     3511      962.0
# 1  2022-10-02  23548      6366        6669     3387      941.0
# 2  2022-10-03  24572      6936        6899     3654      940.0
# 3  2022-10-04  24212      6561        6766     3532      960.0
# 4  2022-10-05  23247      6059        6402     3315      923.0

# %%
X = df.drop(['Date','Referrals'], axis=1)
y = df['Referrals']

# %%
xtest = X.iloc[31:, 0:6]
ytest = y.iloc[31:]

# %%
train_data = df.iloc[0:31]
train_data
# Out:
#           Date    DAU  Installs  Uninstalls  Signups  Referrals
# 0   2022-10-01  24071      6630        6994     3511      962.0
# 1   2022-10-02  23548      6366        6669     3387      941.0
# 2   2022-10-03  24572      6936        6899     3654      940.0
# 3   2022-10-04  24212      6561        6766     3532      960.0
# 4   2022-10-05  23247      6059        6402     3315      923.0
# 5   2022-10-06  24330      6230        6780     3288      822.0
# 6   2022-10-07  24213      6925        7073     3562      957.0
# 7   2022-10-08  25099      7826        7790     4110      994.0
# 8   2022-10-09  24099      8937        8149     4114     1016.0
# 9   2022-10-10  25156      8139        8215     4974     1186.0
# 10  2022-10-11  24497      7308        7532     4347     1161.0
# 11  2022-10-12  24152      8020        7867     4404     1193.0
# 12  2022-10-13  24094      7097        7081     4211      987.0
# 13  2022-10-14  21589      6729        7065     3494      860.0
# ...

# %%
x1_train = X.iloc[0:31,]   #training set features 
x1_train.head()
# Out:
#      DAU  Installs  Uninstalls  Signups
# 0  24071      6630        6994     3511
# 1  23548      6366        6669     3387
# 2  24572      6936        6899     3654
# 3  24212      6561        6766     3532
# 4  23247      6059        6402     3315

# %%
x1_train.shape
# Out:
# (31, 4)

# %%
y1_train = y.iloc[0:31,]

# %%
y1_train.to_frame().head()
# Out:
#    Referrals
# 0      962.0
# 1      941.0
# 2      940.0
# 3      960.0
# 4      923.0

# %%
y1_train.shape
# Out:
# (31,)

# %%
x1_train.columns
# Out:
# Index(['DAU', 'Installs', 'Uninstalls', 'Signups'], dtype='object')

# %%
x1_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DAU         31 non-null     int64
#  1   Installs    31 non-null     int64
#  2   Uninstalls  31 non-null     int64
#  3   Signups     31 non-null     int64
# dtypes: int64(4)
# memory usage: 1.1 KB

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x1_train, y1_train ,test_size = 0.3 , random_state= 42)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train.shape
# Out:
# (21, 4)

# %%
x_test.shape
# Out:
# (10, 4)

# %%
y_train.shape
# Out:
# (21,)

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(x_train ,y_train)
y_prediction = LR.predict(x_test)
y_prediction
# Out:
# array([ 525.68523201,  825.58912755,  422.96857832,  648.75490874,
#        1015.90948411, 1286.36543076,  565.90039098,  476.17830767,
#        1121.75618203,  927.09354134])

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
score = r2_score(y_test, y_prediction)

# %%
print('r2 score', score)
# Out:
# r2 score 0.884047585709202

# %%
import numpy as np 
print('mean_sqrd_error is ==', mean_squared_error(y_test, y_prediction))
print('root_mean_squared error of is == ', np.sqrt(mean_squared_error(y_test, y_prediction)))
# Out:
# mean_sqrd_error is == 9072.807970501202
# root_mean_squared error of is ==  95.25128855034562

# %%
xtest.head()
# Out:
#       DAU  Installs  Uninstalls  Signups
# 31  12816      3763        4149     1806
# 32  12812      3087        3868     1550
# 33  12042      3176        3815     1410
# 34  12595      3172        3878     1629
# 35  12361      3390        4021     1578

# %%
ytest.to_frame().head()
# Out:
#     Referrals
# 31        NaN
# 32        NaN
# 33        NaN
# 34        NaN
# 35        NaN

# %%
xtest.head()
# Out:
#       DAU  Installs  Uninstalls  Signups
# 31  12816      3763        4149     1806
# 32  12812      3087        3868     1550
# 33  12042      3176        3815     1410
# 34  12595      3172        3878     1629
# 35  12361      3390        4021     1578

# %%
xtest1 = scaler.transform(xtest)   #input for trained model in data set

# %%
result = LR.predict(xtest1)
result
# Out:
# array([527.10155454, 475.25828189, 430.06672189, 495.32073188,
#        468.98620996, 493.89434816, 462.87663487, 517.08957217,
#        556.87369765, 564.07754392, 579.96659434, 561.9268456 ,
#        594.23680472, 597.50434999, 764.34537203])

# %%
Result = pd.DataFrame(result)
Result
# Out:
#              0
# 0   527.101555
# 1   475.258282
# 2   430.066722
# 3   495.320732
# 4   468.986210
# 5   493.894348
# 6   462.876635
# 7   517.089572
# 8   556.873698
# 9   564.077544
# 10  579.966594
# 11  561.926846
# 12  594.236805
# 13  597.504350
# 14  764.345372

# %%
xtest_a = np.append( xtest,Result, axis =1)
xtest_a = pd.DataFrame(xtest_a)

# %%
xtest_a
# Out:
#           0       1       2       3           4
# 0   12816.0  3763.0  4149.0  1806.0  527.101555
# 1   12812.0  3087.0  3868.0  1550.0  475.258282
# 2   12042.0  3176.0  3815.0  1410.0  430.066722
# 3   12595.0  3172.0  3878.0  1629.0  495.320732
# 4   12361.0  3390.0  4021.0  1578.0  468.986210
# 5   13166.0  3441.0  4071.0  1656.0  493.894348
# 6   12565.0  3468.0  4011.0  1556.0  462.876635
# 7   12988.0  4468.0  4143.0  1808.0  517.089572
# 8   12992.0  4491.0  4638.0  2017.0  556.873698
# 9   13377.0  4261.0  4480.0  1997.0  564.077544
# 10  13826.0  4274.0  4512.0  2047.0  579.966594
# 11  13464.0  4660.0  4856.0  2066.0  561.926846
# 12  13415.0  4416.0  4749.0  2147.0  594.236805
# 13  13873.0  4097.0  4305.0  2065.0  597.504350
# 14  14459.0  4890.0  4593.0  2707.0  764.345372

# %%
xtest_a.rename({0:'DAU', 1:'Installs', 2:'Uninstalls',3:'Signups', 4:'Referrals'}, inplace = True, axis =1)
xtest_a
# Out:
#         DAU  Installs  Uninstalls  Signups   Referrals
# 0   12816.0    3763.0      4149.0   1806.0  527.101555
# 1   12812.0    3087.0      3868.0   1550.0  475.258282
# 2   12042.0    3176.0      3815.0   1410.0  430.066722
# 3   12595.0    3172.0      3878.0   1629.0  495.320732
# 4   12361.0    3390.0      4021.0   1578.0  468.986210
# 5   13166.0    3441.0      4071.0   1656.0  493.894348
# 6   12565.0    3468.0      4011.0   1556.0  462.876635
# 7   12988.0    4468.0      4143.0   1808.0  517.089572
# 8   12992.0    4491.0      4638.0   2017.0  556.873698
# 9   13377.0    4261.0      4480.0   1997.0  564.077544
# 10  13826.0    4274.0      4512.0   2047.0  579.966594
# 11  13464.0    4660.0      4856.0   2066.0  561.926846
# 12  13415.0    4416.0      4749.0   2147.0  594.236805
# 13  13873.0    4097.0      4305.0   2065.0  597.504350
# 14  14459.0    4890.0      4593.0   2707.0  764.345372

# %% [markdown]
# DAU	Installs	Uninstalls	Signups	Referrals

# %%
Date=pd.DataFrame(df.iloc[31:,0])

# %%
#Date =Date.reset_index()
Date
# Out:
#           Date
# 31  2022-11-01
# 32  2022-11-02
# 33  2022-11-03
# 34  2022-11-04
# 35  2022-11-05
# 36  2022-11-06
# 37  2022-11-07
# 38  2022-11-08
# 39  2022-11-09
# 40  2022-11-10
# 41  2022-11-11
# 42  2022-11-12
# 43  2022-11-13
# 44  2022-11-14
# 45  2022-11-15

# %%
Date.index = np.arange(1,len(Date)+1)
Date
# Out:
#           Date
# 1   2022-11-01
# 2   2022-11-02
# 3   2022-11-03
# 4   2022-11-04
# 5   2022-11-05
# 6   2022-11-06
# 7   2022-11-07
# 8   2022-11-08
# 9   2022-11-09
# 10  2022-11-10
# 11  2022-11-11
# 12  2022-11-12
# 13  2022-11-13
# 14  2022-11-14
# 15  2022-11-15

# %%
Date.shape
# Out:
# (15, 2)

# %%
xtest_a.index = np.arange(1,len(Date)+1)
xtest_2 =xtest_a
xtest_2
# Out:
#         DAU  Installs  Uninstalls  Signups   Referrals
# 1   12816.0    3763.0      4149.0   1806.0  527.101555
# 2   12812.0    3087.0      3868.0   1550.0  475.258282
# 3   12042.0    3176.0      3815.0   1410.0  430.066722
# 4   12595.0    3172.0      3878.0   1629.0  495.320732
# 5   12361.0    3390.0      4021.0   1578.0  468.986210
# 6   13166.0    3441.0      4071.0   1656.0  493.894348
# 7   12565.0    3468.0      4011.0   1556.0  462.876635
# 8   12988.0    4468.0      4143.0   1808.0  517.089572
# 9   12992.0    4491.0      4638.0   2017.0  556.873698
# 10  13377.0    4261.0      4480.0   1997.0  564.077544
# 11  13826.0    4274.0      4512.0   2047.0  579.966594
# 12  13464.0    4660.0      4856.0   2066.0  561.926846
# 13  13415.0    4416.0      4749.0   2147.0  594.236805
# 14  13873.0    4097.0      4305.0   2065.0  597.504350
# 15  14459.0    4890.0      4593.0   2707.0  764.345372

# %%
xtest_2['Date'] = Date
xtest_2
# Out:
#         DAU  Installs  Uninstalls  Signups   Referrals        Date
# 1   12816.0    3763.0      4149.0   1806.0  527.101555  2022-11-01
# 2   12812.0    3087.0      3868.0   1550.0  475.258282  2022-11-02
# 3   12042.0    3176.0      3815.0   1410.0  430.066722  2022-11-03
# 4   12595.0    3172.0      3878.0   1629.0  495.320732  2022-11-04
# 5   12361.0    3390.0      4021.0   1578.0  468.986210  2022-11-05
# 6   13166.0    3441.0      4071.0   1656.0  493.894348  2022-11-06
# 7   12565.0    3468.0      4011.0   1556.0  462.876635  2022-11-07
# 8   12988.0    4468.0      4143.0   1808.0  517.089572  2022-11-08
# 9   12992.0    4491.0      4638.0   2017.0  556.873698  2022-11-09
# 10  13377.0    4261.0      4480.0   1997.0  564.077544  2022-11-10
# 11  13826.0    4274.0      4512.0   2047.0  579.966594  2022-11-11
# 12  13464.0    4660.0      4856.0   2066.0  561.926846  2022-11-12
# 13  13415.0    4416.0      4749.0   2147.0  594.236805  2022-11-13
# ...

# %%
xtest_2 .index = np.arange(1,len(xtest)+1)

# %%
Final_test_data =xtest_2 [['Date','DAU','Installs','Uninstalls','Signups','Referrals']]

# %%
Final_test_data
# Out:
#           Date      DAU  Installs  Uninstalls  Signups   Referrals
# 1   2022-11-01  12816.0    3763.0      4149.0   1806.0  527.101555
# 2   2022-11-02  12812.0    3087.0      3868.0   1550.0  475.258282
# 3   2022-11-03  12042.0    3176.0      3815.0   1410.0  430.066722
# 4   2022-11-04  12595.0    3172.0      3878.0   1629.0  495.320732
# 5   2022-11-05  12361.0    3390.0      4021.0   1578.0  468.986210
# 6   2022-11-06  13166.0    3441.0      4071.0   1656.0  493.894348
# 7   2022-11-07  12565.0    3468.0      4011.0   1556.0  462.876635
# 8   2022-11-08  12988.0    4468.0      4143.0   1808.0  517.089572
# 9   2022-11-09  12992.0    4491.0      4638.0   2017.0  556.873698
# 10  2022-11-10  13377.0    4261.0      4480.0   1997.0  564.077544
# 11  2022-11-11  13826.0    4274.0      4512.0   2047.0  579.966594
# 12  2022-11-12  13464.0    4660.0      4856.0   2066.0  561.926846
# 13  2022-11-13  13415.0    4416.0      4749.0   2147.0  594.236805
# ...

# %%
train_data
# Out:
#           Date    DAU  Installs  Uninstalls  Signups  Referrals
# 0   2022-10-01  24071      6630        6994     3511      962.0
# 1   2022-10-02  23548      6366        6669     3387      941.0
# 2   2022-10-03  24572      6936        6899     3654      940.0
# 3   2022-10-04  24212      6561        6766     3532      960.0
# 4   2022-10-05  23247      6059        6402     3315      923.0
# 5   2022-10-06  24330      6230        6780     3288      822.0
# 6   2022-10-07  24213      6925        7073     3562      957.0
# 7   2022-10-08  25099      7826        7790     4110      994.0
# 8   2022-10-09  24099      8937        8149     4114     1016.0
# 9   2022-10-10  25156      8139        8215     4974     1186.0
# 10  2022-10-11  24497      7308        7532     4347     1161.0
# 11  2022-10-12  24152      8020        7867     4404     1193.0
# 12  2022-10-13  24094      7097        7081     4211      987.0
# 13  2022-10-14  21589      6729        7065     3494      860.0
# ...

# %%
Final_set  =train_data.append(Final_test_data, ignore_index = True)

# %%
Final_set
# Out:
#           Date      DAU  Installs  Uninstalls  Signups    Referrals
# 0   2022-10-01  24071.0    6630.0      6994.0   3511.0   962.000000
# 1   2022-10-02  23548.0    6366.0      6669.0   3387.0   941.000000
# 2   2022-10-03  24572.0    6936.0      6899.0   3654.0   940.000000
# 3   2022-10-04  24212.0    6561.0      6766.0   3532.0   960.000000
# 4   2022-10-05  23247.0    6059.0      6402.0   3315.0   923.000000
# 5   2022-10-06  24330.0    6230.0      6780.0   3288.0   822.000000
# 6   2022-10-07  24213.0    6925.0      7073.0   3562.0   957.000000
# 7   2022-10-08  25099.0    7826.0      7790.0   4110.0   994.000000
# 8   2022-10-09  24099.0    8937.0      8149.0   4114.0  1016.000000
# 9   2022-10-10  25156.0    8139.0      8215.0   4974.0  1186.000000
# 10  2022-10-11  24497.0    7308.0      7532.0   4347.0  1161.000000
# 11  2022-10-12  24152.0    8020.0      7867.0   4404.0  1193.000000
# 12  2022-10-13  24094.0    7097.0      7081.0   4211.0   987.000000
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.figure(figsize = [40, 10]) 
plt.xticks(rotation=90)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.plot(Final_set['Date'], Final_set['Referrals'])
plt.plot(Final_test_data['Date'], Final_test_data['Referrals'], color='red')
plt.title(label="November predicted Referrals",
          fontsize=40,
          color="green")
# Out:
# Text(0.5, 1.0, 'November predicted Referrals')
